# %%
num =45.3
sng='cellar doors'
print("I would like to have" + str(num) +' ' + sng)
# Out:
# I would like to have45.3 cellar doors

# %%
# string interpolation
print('I would like to have %g %s' % (num,sng))
# Out:
# I would like to have 45.3 cellar doors
